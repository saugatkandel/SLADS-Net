# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
#! /usr/bin/env python3
import sys
import warnings
warnings.filterwarnings("ignore")
sys.path.append('code')
import timeit
from pathlib import Path
from IPython.display import display, Markdown

from runSLADSSimulationScript import runSLADSSimulationScript

# %%
###############################################################################
############## USER INPUTS: L-0 ###############################################
###############################################################################
# 2, 9, 10, 11
i = 10  ## the index of testing examples in /ResultsAndData/TestingImages/

# Name of folder to save result in    
FolderName = 'Example_' + str(i)

# Type of Image: D - for discrete (classified) image; C - for continuous
ImageType = 'C'

# Image extention
ImageExtension = '.tif'

# If TestingImageSet_X used enter 'X'
TestingImageSet = str(i)    

# If TrainingDB_Y was used for training enter 'Y'          
TrainingImageSet = '4'

# Image resolution in pixels   
SizeImage = [256,256]

# Value of c found in training     
c = 16

# Maximum  sampling percentage 
StoppingPercentage = 20
# If you want to use stopping function used, enter threshold (from Training), 
# else leave at 0      
StoppingThrehsold = 0

# Clasification setting
Classify = 'N'              
# 'N' - no classification needed (already classified or continuous data)
# '2C' - perform 2 class classification using otsu
# 'MC' - perform multi-class classification
# if 'MC' open .code/runSLADSOnce.py and search "elif Classify=='MC':" and  
# include your classification method (in all four locations) as instructed
                            
# Initial Mask for SLADS:
# Percentage of samples in initial mask
PercentageInitialMask = 1
# Type of initial mask   
MaskType = 'R'                   
# Choices: 
    # 'U': Uniform mask; can choose any percentage
    # 'R': Randomly distributed mask; can choose any percentage
    # 'H': low-dsicrepacy mask; can only choose 1% mask
# Batch Sampling
BatchSample = 'N'           
# If 'Y' set number of samples in each step in L-1 (NumSamplesPerIter)

PlotResult='Y'

# %%
###############################################################################
############## USER INPUTS: L-1 ###############################################
############################################################################### 

# The number of samples in each step  
NumSamplesPerIter = 1         

# Update ERD or compute full ERD in SLADS
# with Update ERD, ERD only updated for a window surrounding new measurement
Update_ERD = 'Y' 
# Smallest ERD update window size permitted
MinWindSize = 3  
# Largest ERD update window size permitted  
MaxWindSize = 10

# %%
for inum in [1, 2, 10, 12]:
    display(Markdown(f'### Set {inum}'))
    
    #img_list = (list(Path(f'ResultsAndData/TestingImages/TestingImageSet_{inum}/').glob('*.tif')) + 
    #            list(Path(f'ResultsAndData/TestingImages/TestingImageSet_{inum}/').glob('*.png')))
    #img = img_list[0]
    #shape_str = img.parts[-1].split('_')[-1].split('.')[0].split('x')

    start = timeit.default_timer()

    # Image resolution in pixels   
    SizeImage = [256, 256]#[int(s) for s in shape_str]

    # Name of folder to save result in    
    FolderName = f'Example_{inum}'

    # Maximum  sampling percentage 
    StoppingPercentage = 40

    for TrainingImageSet in ['6']:
        for TestingImageSet in [f'{inum}']:
            try:
                ImageExtension = '.tif'
                runSLADSSimulationScript(FolderName,ImageType,ImageExtension,
                                         TestingImageSet,TrainingImageSet,SizeImage,c,StoppingPercentage,
                                         StoppingThrehsold,Classify,PercentageInitialMask,MaskType,BatchSample,
                                         PlotResult,NumSamplesPerIter,Update_ERD,MinWindSize,MaxWindSize)
            except:
                ImageExtension = '.png'
                runSLADSSimulationScript(FolderName, ImageType, ImageExtension, TestingImageSet, TrainingImageSet, 
                                         SizeImage, c,
                                         StoppingPercentage, StoppingThrehsold, Classify, 
                                         PercentageInitialMask, MaskType,
                                         BatchSample, PlotResult, NumSamplesPerIter, Update_ERD, 
                                         MinWindSize, MaxWindSize)

    stop = timeit.default_timer()

    print(stop - start)
# Out:
# ### Set 1
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
# Traceback (most recent call last):
#   File "/gpfs/fs1/home/skandel/code/SLADS-Net-orig/code/loader.py", line 26, in loadTestImage
#     Img
# UnboundLocalError: local variable 'Img' referenced before assignment
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/tmp/ipykernel_359850/744440528.py", line 24, in <module>
#     runSLADSSimulationScript(FolderName,ImageType,ImageExtension,
#   File "/gpfs/fs1/home/skandel/code/SLADS-Net-orig/code/runSLADSSimulationScript.py", line 70, in runSLADSSimulationScript
#     runSLADSSimulationOnce(Mask,CodePath,TestingImageSet,SizeImage,StopCondParams,Theta,TrainingInfo,Resolution,ImageType,UpdateERDParams,BatchSamplingParams,SavePath,SimulationRun,ImNum,ImageExtension,PlotResult,Classify)
#   File "/gpfs/fs1/home/skandel/code/SLADS-Net-orig/code/runSLADSOnce.py", line 35, in runSLADSSimulationOnce
#     ContinuousMeasuredValues = perfromInitialMeasurements(CodePath,ImageSet,ImNum,ImageExtension,Mask,SimulationRun)
#   File "/gpfs/fs1/home/skandel/code/SLADS-Net-orig/code/performMeasurements.py", line 11, in perfromInitialMeasurements
#     Img = loadTestImage(CodePath,TestingImageSet,ImNum,ImageExtension,SimulationRun)
#   File "/gpfs/fs1/home/skandel/code/SLADS-Net-orig/code/loader.py", line 28, in loadTestImage
#     sys.exit('Error!!! There are no images in ' + loadPathImage + ' that have the extention ' + ImageExtension)
# SystemExit: Error!!! There are no images in ./ResultsAndData/TestingImages/TestingImageSet_1/ that have the extention .tif
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/skandel/.conda/envs/pytorch1/lib/python3.9/site-packages/IPython/core/interactiveshell.py", line 3457, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "/tmp/ipykernel_359850/744440528.py", line 30, in <module>
#     runSLADSSimulationScript(FolderName, ImageType, ImageExtension, TestingImageSet, TrainingImageSet,
#   File "/gpfs/fs1/home/skandel/code/SLADS-Net-orig/code/runSLADSSimulationScript.py", line 70, in runSLADSSimulationScript
#     runSLADSSimulationOnce(Mask,CodePath,TestingImageSet,SizeImage,StopCondParams,Theta,TrainingInfo,Resolution,ImageType,UpdateERDParams,BatchSamplingParams,SavePath,SimulationRun,ImNum,ImageExtension,PlotResult,Classify)
#   File "/gpfs/fs1/home/skandel/code/SLADS-Net-orig/code/runSLADSOnce.py", line 35, in runSLADSSimulationOnce
#     ContinuousMeasuredValues = perfromInitialMeasurements(CodePath,ImageSet,ImNum,ImageExtension,Mask,SimulationRun)
#   File "/gpfs/fs1/home/skandel/code/SLADS-Net-orig/code/performMeasurements.py", line 13, in perfromInitialMeasurements
#     sys.exit('Error!!! The dimensions you entered in "SizeImage" do not match the dimensions of the testing image in ./ResultsAndData/TestingImages/TestingImageSet_' + TestingImageSet)
# SystemExit: Error!!! The dimensions you entered in "SizeImage" do not match the dimensions of the testing image in ./ResultsAndData/TestingImages/TestingImageSet_1
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/skandel/.conda/envs/pytorch1/lib/python3.9/site-packages/IPython/core/ultratb.py", line 1101, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#   File "/home/skandel/.conda/envs/pytorch1/lib/python3.9/site-packages/IPython/core/ultratb.py", line 248, in wrapped
#     return f(*args, **kwargs)
#   File "/home/skandel/.conda/envs/pytorch1/lib/python3.9/site-packages/IPython/core/ultratb.py", line 281, in _fixed_getinnerframes
#     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#   File "/home/skandel/.conda/envs/pytorch1/lib/python3.9/inspect.py", line 1541, in getinnerframes
#     frameinfo = (tb.tb_frame,) + getframeinfo(tb, context)
# AttributeError: 'tuple' object has no attribute 'tb_frame'
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# /gpfs/fs1/home/skandel/code/SLADS-Net-orig/code/loader.py in loadTestImage(CodePath, ImageSet, ImNum, ImageExtension, SimulationRun)
#      25     try:
# ---> 26         Img
#      27     except NameError:
#
# UnboundLocalError: local variable 'Img' referenced before assignment
#
# During handling of the above exception, another exception occurred:
#
# SystemExit                                Traceback (most recent call last)
# /tmp/ipykernel_359850/744440528.py in <module>
#      23                 ImageExtension = '.tif'
# ---> 24                 runSLADSSimulationScript(FolderName,ImageType,ImageExtension,
#      25                                          TestingImageSet,TrainingImageSet,SizeImage,c,StoppingPercentage,
#
# /gpfs/fs1/home/skandel/code/SLADS-Net-orig/code/runSLADSSimulationScript.py in runSLADSSimulationScript(FolderName, ImageType, ImageExtension, TestingImageSet, TrainingImageSet, SizeImage, c, StoppingPercentage, StoppingThrehsold, Classify, PercentageInitialMask, MaskType, BatchSample, PlotResult, NumSamplesPerIter, Update_ERD, MinWindSize, MaxWindSize)
#      69     ImNum = 1
# ---> 70     runSLADSSimulationOnce(Mask,CodePath,TestingImageSet,SizeImage,StopCondParams,Theta,TrainingInfo,Resolution,ImageType,UpdateERDParams,BatchSamplingParams,SavePath,SimulationRun,ImNum,ImageExtension,PlotResult,Classify)
#
# /gpfs/fs1/home/skandel/code/SLADS-Net-orig/code/runSLADSOnce.py in runSLADSSimulationOnce(Mask, CodePath, ImageSet, SizeImage, StopCondParams, Theta, TrainingInfo, Resolution, ImageType, UpdateERDParams, BatchSamplingParams, SavePath, SimulationRun, ImNum, ImageExtension, PlotResult, Classify)
#      34
# ---> 35     ContinuousMeasuredValues = perfromInitialMeasurements(CodePath,ImageSet,ImNum,ImageExtension,Mask,SimulationRun)
#      36
#
# /gpfs/fs1/home/skandel/code/SLADS-Net-orig/code/performMeasurements.py in perfromInitialMeasurements(CodePath, TestingImageSet, ImNum, ImageExtension, Mask, SimulationRun)
#      10
# ---> 11     Img = loadTestImage(CodePath,TestingImageSet,ImNum,ImageExtension,SimulationRun)
#      12     if Mask.shape[0]!=Img.shape[0] or Mask.shape[1]!=Img.shape[1]:
#
# /gpfs/fs1/home/skandel/code/SLADS-Net-orig/code/loader.py in loadTestImage(CodePath, ImageSet, ImNum, ImageExtension, SimulationRun)
#      27     except NameError:
# ---> 28         sys.exit('Error!!! There are no images in ' + loadPathImage + ' that have the extention ' + ImageExtension)
#      29     return Img
#
# SystemExit: Error!!! There are no images in ./ResultsAndData/TestingImages/TestingImageSet_1/ that have the extention .tif
#
# During handling of the above exception, another exception occurred:
#
# SystemExit                                Traceback (most recent call last)
#     [... skipping hidden 1 frame]
#
# /tmp/ipykernel_359850/744440528.py in <module>
#      29                 ImageExtension = '.png'
# ---> 30                 runSLADSSimulationScript(FolderName, ImageType, ImageExtension, TestingImageSet, TrainingImageSet,
#      31                                          SizeImage, c,
#
# /gpfs/fs1/home/skandel/code/SLADS-Net-orig/code/runSLADSSimulationScript.py in runSLADSSimulationScript(FolderName, ImageType, ImageExtension, TestingImageSet, TrainingImageSet, SizeImage, c, StoppingPercentage, StoppingThrehsold, Classify, PercentageInitialMask, MaskType, BatchSample, PlotResult, NumSamplesPerIter, Update_ERD, MinWindSize, MaxWindSize)
#      69     ImNum = 1
# ---> 70     runSLADSSimulationOnce(Mask,CodePath,TestingImageSet,SizeImage,StopCondParams,Theta,TrainingInfo,Resolution,ImageType,UpdateERDParams,BatchSamplingParams,SavePath,SimulationRun,ImNum,ImageExtension,PlotResult,Classify)
#
# /gpfs/fs1/home/skandel/code/SLADS-Net-orig/code/runSLADSOnce.py in runSLADSSimulationOnce(Mask, CodePath, ImageSet, SizeImage, StopCondParams, Theta, TrainingInfo, Resolution, ImageType, UpdateERDParams, BatchSamplingParams, SavePath, SimulationRun, ImNum, ImageExtension, PlotResult, Classify)
#      34
# ---> 35     ContinuousMeasuredValues = perfromInitialMeasurements(CodePath,ImageSet,ImNum,ImageExtension,Mask,SimulationRun)
#      36
#
# /gpfs/fs1/home/skandel/code/SLADS-Net-orig/code/performMeasurements.py in perfromInitialMeasurements(CodePath, TestingImageSet, ImNum, ImageExtension, Mask, SimulationRun)
#      12     if Mask.shape[0]!=Img.shape[0] or Mask.shape[1]!=Img.shape[1]:
# ---> 13         sys.exit('Error!!! The dimensions you entered in "SizeImage" do not match the dimensions of the testing image in ./ResultsAndData/TestingImages/TestingImageSet_' + TestingImageSet)
#      14     MeasuredValues = Img[Mask==1]
#
# SystemExit: Error!!! The dimensions you entered in "SizeImage" do not match the dimensions of the testing image in ./ResultsAndData/TestingImages/TestingImageSet_1
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
#     [... skipping hidden 1 frame]
#
# ~/.conda/envs/pytorch1/lib/python3.9/site-packages/IPython/core/interactiveshell.py in showtraceback(self, exc_tuple, filename, tb_offset, exception_only, running_compiled_code)
#    2068                     stb = ['An exception has occurred, use %tb to see '
#    2069                            'the full traceback.\n']
# -> 2070                     stb.extend(self.InteractiveTB.get_exception_only(etype,
#    2071                                                                      value))
#    2072                 else:
#
# ~/.conda/envs/pytorch1/lib/python3.9/site-packages/IPython/core/ultratb.py in get_exception_only(self, etype, value)
#     752         value : exception value
#     753         """
# --> 754         return ListTB.structured_traceback(self, etype, value)
#     755
#     756     def show_exception_only(self, etype, evalue):
#
# ~/.conda/envs/pytorch1/lib/python3.9/site-packages/IPython/core/ultratb.py in structured_traceback(self, etype, evalue, etb, tb_offset, context)
#     627             chained_exceptions_tb_offset = 0
#     628             out_list = (
# --> 629                 self.structured_traceback(
#     630                     etype, evalue, (etb, chained_exc_ids),
#     631                     chained_exceptions_tb_offset, context)
#
# ~/.conda/envs/pytorch1/lib/python3.9/site-packages/IPython/core/ultratb.py in structured_traceback(self, etype, value, tb, tb_offset, number_of_lines_of_context)
#    1365         else:
#    1366             self.tb = tb
# -> 1367         return FormattedTB.structured_traceback(
#    1368             self, etype, value, tb, tb_offset, number_of_lines_of_context)
#    1369
#
# ~/.conda/envs/pytorch1/lib/python3.9/site-packages/IPython/core/ultratb.py in structured_traceback(self, etype, value, tb, tb_offset, number_of_lines_of_context)
#    1265         if mode in self.verbose_modes:
#    1266             # Verbose modes need a full traceback
# -> 1267             return VerboseTB.structured_traceback(
#    1268                 self, etype, value, tb, tb_offset, number_of_lines_of_context
#    1269             )
#
# ~/.conda/envs/pytorch1/lib/python3.9/site-packages/IPython/core/ultratb.py in structured_traceback(self, etype, evalue, etb, tb_offset, number_of_lines_of_context)
#    1122         """Return a nice text document describing the traceback."""
#    1123
# -> 1124         formatted_exception = self.format_exception_as_a_whole(etype, evalue, etb, number_of_lines_of_context,
#    1125                                                                tb_offset)
#    1126
#
# ~/.conda/envs/pytorch1/lib/python3.9/site-packages/IPython/core/ultratb.py in format_exception_as_a_whole(self, etype, evalue, etb, number_of_lines_of_context, tb_offset)
#    1080
#    1081
# -> 1082         last_unique, recursion_repeat = find_recursion(orig_etype, evalue, records)
#    1083
#    1084         frames = self.format_records(records, last_unique, recursion_repeat)
#
# ~/.conda/envs/pytorch1/lib/python3.9/site-packages/IPython/core/ultratb.py in find_recursion(etype, value, records)
#     380     # first frame (from in to out) that looks different.
#     381     if not is_recursion_error(etype, value, records):
# --> 382         return len(records), 0
#     383
#     384     # Select filename, lineno, func_name to track frames with
#
# TypeError: object of type 'NoneType' has no len()
